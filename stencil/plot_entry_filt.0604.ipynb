# %% [markdown]
# # Filtering TM/TR CDF plot (0603)
#
# Set `DATA_FOLDER`, then run all cells. This notebook only draws the original CDF data up to `QUANTILE_DROP=0.995`; it does not drop data and does not renormalize the CDF.

# %%
from pathlib import Path
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA_FOLDERS = [
    Path('/astrum/home/hpchzy/code/data/20260604/c920bn3/output_filt/20260604-103059/'),     # c920bn3, dsub
    Path('/astrum/home/hpchzy/code/data/20260604/camd9554n2/output_filt/20260604-103123/'),  # camd9554n2, dsub
    Path('/astrum/home/hpchzy/code/data/20260604/cgnr6760pn2/output_filt/20260604-103109/'), # cgnr6760pn2, dsub
]

QUANTILE_DROP = 0.995  # only draw CDF values from 0 to 0.995; no data deletion, no renormalization
SAVE_FIG = False
OUT_DIR = Path('/astrum/home/hpchzy/code/TacVar/stencil/plots_0604')

TIMER_COLORS = {
    'cgt': '#ff7f0e',
    'clock_gettime': '#ff7f0e',
    'wtime': '#2ca02c',
    'mpi_wtime': '#2ca02c',
    'papi': '#d62728',
    'papix6': '#9467bd',
    'likwid': '#8c564b',
    'tsc': '#1f77b4',
    'tsc_fence': '#4f8dd3',
    'tsc_native': '#17becf',
    'cntvct': '#00a6d6',
    'cntvcto': '#e377c2',
}

TIMER_LABELS = {
    'tsc': 'TSC',
    'tsc_fence': 'TSC_Fence',
    'tsc_native': 'TSC_Native',
    'cgt': 'clock_gettime',
    'clock_gettime': 'clock_gettime',
    'wtime': 'MPI_Wtime',
    'mpi_wtime': 'MPI_Wtime',
    'papi': 'PAPI',
    'papix6': 'PAPIx6',
    'likwid': 'LIKWID',
    'cntvct': 'CNTVCT',
    'cntvcto': 'CNTVCTO',
}

KERNEL_LABELS = {
    'jacobi2d5p': '2D 5-Point Jacobi Stencil',
}

HOST_LABELS = {
    'c920bn3': 'Kunpeng 920B',
    'camd9554n2': 'AMD EPYC 9554',
    'cgnr6760pn2': 'Intel Xeon 6760P',
}

# %%
def parse_filt_dir(path):
    m = re.match(r'(?P<kernel>.+)_(?P<timer>.+)_np(?P<np>\d+)_size(?P<size>\d+)_filt$', path.name)
    if not m:
        return None
    d = m.groupdict()
    d['np'] = int(d['np'])
    d['size'] = int(d['size'])
    return d


def host_from_data_folder(data_folder):
    parts = Path(data_folder).parts
    if 'data' in parts:
        i = parts.index('data')
        if len(parts) > i + 2:
            return parts[i + 2]
    return Path(data_folder).name


def timer_label(timer):
    return TIMER_LABELS.get(timer, timer.upper().replace('_', '-'))


def timer_sort_key(timer):
    order = ['tsc', 'tsc_fence', 'tsc_native', 'cgt', 'clock_gettime', 'wtime', 'mpi_wtime', 'papi', 'papix6', 'likwid', 'cntvct', 'cntvcto']
    return (order.index(timer) if timer in order else len(order), timer)


def ecdf_xy(vals):
    vals = np.asarray(vals, dtype=float)
    vals = vals[np.isfinite(vals)]
    vals = np.sort(vals)
    if vals.size == 0:
        return vals, vals
    y = np.arange(1, vals.size + 1) / vals.size
    keep = y <= QUANTILE_DROP
    return vals[keep], y[keep]


def read_tm(tm_file):
    df = pd.read_csv(tm_file, header=None, names=['ns'])
    return df['ns'].to_numpy()


def read_tr(tr_hist_file):
    df = pd.read_csv(tr_hist_file, header=None, names=['ns', 'prob'])
    df['ns'] = pd.to_numeric(df['ns'], errors='coerce')
    df['prob'] = pd.to_numeric(df['prob'], errors='coerce')
    df = df[np.isfinite(df['ns']) & np.isfinite(df['prob'])].copy()
    df = df[df['prob'] > 0]
    df.sort_values('ns', inplace=True)
    df['cdf'] = df['prob'].cumsum()
    if len(df) and df['cdf'].iloc[-1] != 0:
        df['cdf'] = df['cdf'] / df['cdf'].iloc[-1]
    return df[df['cdf'] <= QUANTILE_DROP]


def collect_entries(data_folder):
    rows = []
    data_folder = Path(data_folder)
    host = host_from_data_folder(data_folder)
    for tr_hist_file in sorted(data_folder.glob('*/tr_hist.csv')):
        filt_dir = tr_hist_file.parent
        meta = parse_filt_dir(filt_dir)
        if meta is None:
            continue
        tm_file = filt_dir / 'met.csv'
        if not tm_file.exists():
            print(f'skip missing met.csv: {filt_dir}')
            continue
        rows.append({**meta, 'host': host, 'data_folder': data_folder, 'filt_dir': filt_dir, 'tm_file': tm_file, 'tr_hist_file': tr_hist_file})
    return pd.DataFrame(rows)

entries = pd.concat([collect_entries(p) for p in DATA_FOLDERS], ignore_index=True)
print(f'entries: {len(entries)}')
entries.sort_values(['host', 'kernel', 'np', 'size', 'timer']).head(20)
# Out:
# entries: 114
#         kernel   timer  np  size     host  \
# 5   jacobi2d5p     cgt  64    64  c920bn3
# 11  jacobi2d5p  cntvct  64    64  c920bn3
# 17  jacobi2d5p    papi  64    64  c920bn3
# 23  jacobi2d5p  papix6  64    64  c920bn3
# 29  jacobi2d5p   wtime  64    64  c920bn3
# 1   jacobi2d5p     cgt  64   128  c920bn3
# 7   jacobi2d5p  cntvct  64   128  c920bn3
# 13  jacobi2d5p    papi  64   128  c920bn3
# 19  jacobi2d5p  papix6  64   128  c920bn3
# 25  jacobi2d5p   wtime  64   128  c920bn3
# 3   jacobi2d5p     cgt  64   256  c920bn3
# 9   jacobi2d5p  cntvct  64   256  c920bn3
# 15  jacobi2d5p    papi  64   256  c920bn3
# 21  jacobi2d5p  papix6  64   256  c920bn3
# 27  jacobi2d5p   wtime  64   256  c920bn3
# 4   jacobi2d5p     cgt  64   512  c920bn3
# 10  jacobi2d5p  cntvct  64   512  c920bn3
# 16  jacobi2d5p    papi  64   512  c920bn3
# 22  jacobi2d5p  papix6  64   512  c920bn3
# 28  jacobi2d5p   wtime  64   512  c920bn3
#
#                                           data_folder  \
# 5   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 11  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 17  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 23  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 29  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 1   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 7   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 13  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 19  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 25  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 3   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 9   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 15  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 21  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 27  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 4   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 10  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 16  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 22  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 28  /astrum/home/hpchzy/code/data/20260604/c920bn3...
#
#                                              filt_dir  \
# 5   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 11  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 17  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 23  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 29  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 1   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 7   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 13  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 19  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 25  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 3   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 9   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 15  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 21  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 27  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 4   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 10  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 16  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 22  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 28  /astrum/home/hpchzy/code/data/20260604/c920bn3...
#
#                                               tm_file  \
# 5   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 11  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 17  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 23  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 29  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 1   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 7   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 13  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 19  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 25  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 3   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 9   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 15  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 21  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 27  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 4   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 10  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 16  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 22  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 28  /astrum/home/hpchzy/code/data/20260604/c920bn3...
#
#                                          tr_hist_file
# 5   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 11  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 17  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 23  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 29  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 1   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 7   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 13  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 19  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 25  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 3   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 9   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 15  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 21  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 27  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 4   /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 10  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 16  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 22  /astrum/home/hpchzy/code/data/20260604/c920bn3...
# 28  /astrum/home/hpchzy/code/data/20260604/c920bn3...

# %% [markdown]
# # ER/EP/Wasserstein

# %%
from scipy.stats import wasserstein_distance


def read_float_file(path):
    try:
        text = Path(path).read_text().strip()
        return float(text) if text else np.nan
    except FileNotFoundError:
        print(f'warning: missing {path}')
        return np.nan
    except ValueError:
        print(f'warning: invalid float in {path}')
        return np.nan


def clean_hist_for_wd(hist_file, ns_col='ns', pr_col='pr'):
    df = pd.read_csv(hist_file, header=None, names=[ns_col, pr_col])
    df[ns_col] = pd.to_numeric(df[ns_col], errors='coerce')
    df[pr_col] = pd.to_numeric(df[pr_col], errors='coerce')
    df = df[np.isfinite(df[ns_col]) & np.isfinite(df[pr_col])].copy()
    df = df[df[pr_col] > 0]
    if df.empty or df[pr_col].sum() <= 0:
        return None
    return df


def wd_to_min(hist_file):
    df = clean_hist_for_wd(hist_file)
    if df is None:
        return np.nan
    ns = df['ns'].to_numpy(dtype=float)
    pr = df['pr'].to_numpy(dtype=float)
    return wasserstein_distance(ns, np.array([ns.min()]), pr, np.array([1.0]))


summary_rows = []
for idx, row in entries.iterrows():
    filt_folder = Path(row['filt_dir'])
    ep = read_float_file(filt_folder / 'ep.out')
    er = read_float_file(filt_folder / 'er.out')
    wd = read_float_file(filt_folder / 'wd.out')
    tm_wd = wd_to_min(filt_folder / 'tm_hist.csv')
    tr_wd = wd_to_min(filt_folder / 'tr_hist.csv')
    if not np.isfinite(tm_wd) or not np.isfinite(tr_wd):
        print(f"warning: invalid histogram for Wasserstein: {filt_folder.name} tm_wd={tm_wd} tr_wd={tr_wd}")
    summary_rows.append({**row.to_dict(), 'ep': ep, 'er': er, 'wd': wd, 'tm_wd': tm_wd, 'tr_wd': tr_wd})

df = pd.DataFrame(summary_rows).reset_index(drop=True)
df.sort_values(['host', 'kernel', 'np', 'size', 'timer'], inplace=True)
df[['host', 'kernel', 'timer', 'np', 'size', 'ep', 'er', 'wd', 'tm_wd', 'tr_wd']].head(20)
# Out:
# warning: invalid histogram for Wasserstein: jacobi2d5p_cgt_np64_size256_filt tm_wd=12.357494348982815 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_cntvct_np64_size128_filt tm_wd=0.0 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_cntvct_np64_size256_filt tm_wd=6.245821722840441 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_cntvct_np64_size512_filt tm_wd=266.38484393610435 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_papi_np64_size256_filt tm_wd=14.537859608745686 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_papi_np64_size512_filt tm_wd=303.67538548623565 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_tsc_native_np64_size256_filt tm_wd=8.965003954383752 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_tsc_np64_size256_filt tm_wd=11.476312721122138 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_wtime_np64_size256_filt tm_wd=12.333702693999356 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_wtime_np64_size512_filt tm_wd=160.6084290957824 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_cgt_np64_size128_filt tm_wd=0.0 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_cgt_np64_size256_filt tm_wd=2.182456940390083 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_likwid_np64_size128_filt tm_wd=13.622082693046488 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_likwid_np64_size64_filt tm_wd=6.437178802039592 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_tsc_native_np64_size128_filt tm_wd=0.8726145620519021 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_wtime_np64_size128_filt tm_wd=0.0 tr_wd=nan
# warning: invalid histogram for Wasserstein: jacobi2d5p_wtime_np64_size256_filt tm_wd=0.8689871271170913 tr_wd=nan
#        host      kernel   timer  np  size        ep        er          wd  \
# 5   c920bn3  jacobi2d5p     cgt  64    64  0.074289  0.053760    4.313568
# 11  c920bn3  jacobi2d5p  cntvct  64    64  0.556112  0.058271    4.018090
# 17  c920bn3  jacobi2d5p    papi  64    64  0.001089  0.071201   15.061307
# 23  c920bn3  jacobi2d5p  papix6  64    64  0.001038  0.105453   22.809045
# 29  c920bn3  jacobi2d5p   wtime  64    64  0.203972  0.138440   11.349749
# 1   c920bn3  jacobi2d5p     cgt  64   128  0.104242  0.026629    3.988945
# 7   c920bn3  jacobi2d5p  cntvct  64   128  1.000000  1.000000  123.376884
# 13  c920bn3  jacobi2d5p    papi  64   128  0.020003  0.052439   14.340704
# 19  c920bn3  jacobi2d5p  papix6  64   128  0.005048  0.081372   22.609045
# 25  c920bn3  jacobi2d5p   wtime  64   128  0.246598  0.048329    7.349749
# 3   c920bn3  jacobi2d5p     cgt  64   256       inf  0.847465  222.179899
# 9   c920bn3  jacobi2d5p  cntvct  64   256  1.000000  0.973130  227.193970
# 15  c920bn3  jacobi2d5p    papi  64   256       inf  0.534382  205.448241
# 21  c920bn3  jacobi2d5p  papix6  64   256  0.000161  0.056471   21.918593
# 27  c920bn3  jacobi2d5p   wtime  64   256  0.928986  0.026825    7.144724
# 4   c920bn3  jacobi2d5p     cgt  64   512  0.012976  0.197643  207.607035
# 10  c920bn3  jacobi2d5p  cntvct  64   512       inf  0.809046  644.512563
# 16  c920bn3  jacobi2d5p    papi  64   512  1.000000  0.707528  709.816080
# 22  c920bn3  jacobi2d5p  papix6  64   512  0.084332  0.207457  205.518593
# 28  c920bn3  jacobi2d5p   wtime  64   512  0.096568  0.312453  324.795980
#
#          tm_wd       tr_wd
# 5     9.511597    9.511600
# 11    8.878144    0.000000
# 17   11.598471   11.598458
# 23    6.345086    6.345090
# 29    0.000000    0.000000
# 1    17.386188   17.386180
# 7     0.000000         NaN
# 13   13.208411   13.208400
# 19   15.199602   15.199610
# 25   18.932338   18.932340
# 3    12.357494         NaN
# 9     6.245822         NaN
# 15   14.537860         NaN
# 21   15.222156   15.222130
# 27   11.266692    0.000000
# 4   490.173706  271.993392
# 10  266.384844         NaN
# 16  303.675385         NaN
# 22  300.960325   68.744440
# 28  479.072181  139.573870

# %%
df["timer_label"] = df["timer"].map(TIMER_LABELS).fillna(df["timer"])
df["kernel_label"] = df["kernel"].map(KERNEL_LABELS).fillna(df["kernel"])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

metric_bar = 'wd'
line_metrics = ['ep', 'er']

plot_df = df.copy()
plot_df['timer_label'] = plot_df['timer'].map(TIMER_LABELS).fillna(plot_df['timer'])
plot_df['size_str'] = plot_df['size'].astype(str)
size_order = [str(x) for x in sorted(plot_df['size'].unique())]
plot_df['size_str'] = pd.Categorical(plot_df['size_str'], categories=size_order, ordered=True)

hosts = [host_from_data_folder(p) for p in DATA_FOLDERS]
fig, axes = plt.subplots(1, len(hosts), figsize=(5.2 * len(hosts), 4), sharey=True, constrained_layout=True)
if len(hosts) == 1:
    axes = [axes]

right_axes = []
for ax1, host in zip(axes, hosts):
    host_df = plot_df[plot_df['host'] == host]
    sns.barplot(data=host_df, x='size_str', y=metric_bar, hue='timer_label', ax=ax1)
    HOSTNAME = host_df['host'].iloc[0]
    # ax1.set_title(f"{KERNEL_LABELS.get(plot_df['kernel'].iloc[0], plot_df['kernel'].iloc[0])} on {HOST_LABELS.get(HOSTNAME, HOSTNAME)}")
    ax1.set_title(f"{HOST_LABELS.get(HOSTNAME, HOSTNAME)}")
    ax1.set_xlabel('Grid Size')
    ax1.set_ylabel('Wasserstein' if ax1 is axes[0] else '')
    ax1.grid(axis='y', linestyle='--', alpha=0.4)

    ax2 = ax1.twinx()
    right_axes.append(ax2)
    line_df = host_df.groupby(['size_str'], observed=True)[line_metrics].mean().reset_index()
    x_pos = range(len(line_df))
    ax2.plot(x_pos, line_df['ep'], marker='o', label='EP', color='black')
    ax2.plot(x_pos, line_df['er'], marker='s', label='ER', color='gray')
    ax2.set_ylabel('EP / ER')
    ax2.set_xticks(list(x_pos))
    ax2.set_xticklabels(line_df['size_str'])

    
    ax1.legend(title='timer', fontsize=8, loc='upper left')
    ax2.legend(title='metric', fontsize=8, loc='upper right')

left_lims = [ax.get_ylim() for ax in axes]
right_lims = [ax.get_ylim() for ax in right_axes]
left_ylim = (min(lo for lo, hi in left_lims), max(hi for lo, hi in left_lims))
right_ylim = (min(lo for lo, hi in right_lims), max(hi for lo, hi in right_lims))
for ax in axes:
    ax.set_ylim(left_ylim)
for ax in right_axes:
    ax.set_ylim(right_ylim)

plt.show()

# %% [markdown]
# # Filt Plot

# %%
# entries_plot = entries[(entries['size'] == 2048) & (entries['timer'] != 'likwid')]
entries_plot = entries[entries['timer'] != 'likwid']



if entries_plot.empty:
    raise RuntimeError('No *_filt/tr_hist.csv entries found for size=2048 under DATA_FOLDERS')

if SAVE_FIG:
    OUT_DIR.mkdir(parents=True, exist_ok=True)

hosts = [host_from_data_folder(p) for p in DATA_FOLDERS]

for (kernel, np_val, size), group_all in entries_plot.groupby(['kernel', 'np', 'size'], sort=True):
    fig, axes = plt.subplots(1, len(hosts), figsize=(6.0 * len(hosts), 4.4), sharey=True, constrained_layout=True)
    if len(hosts) == 1:
        axes = [axes]

    for ax, host in zip(axes, hosts):
        group = group_all[group_all['host'] == host].sort_values('timer', key=lambda s: s.map(timer_sort_key))

        for _, row in group.iterrows():
            timer = row['timer']
            color = TIMER_COLORS.get(timer)
            label = timer_label(timer)

            tm_x, tm_y = ecdf_xy(read_tm(row['tm_file']))
            tr_df = read_tr(row['tr_hist_file'])

            ax.plot(tm_x, tm_y, label=f'{label}-TM', color=color, linestyle='--', linewidth=1.0)
            ax.step(tr_df['ns'], tr_df['cdf'], label=f'{label}-TR', color=color, linestyle='-', linewidth=1.0, where='post')

        ax.set_title(f"{HOST_LABELS.get(host, host)}")
        ax.set_xlabel('time (ns)')
        ax.set_ylim(0, QUANTILE_DROP)
        ax.grid(True, alpha=0.28)
        ax.legend(ncol=2, fontsize=8)

    xlims = [ax.get_xlim() for ax in axes]
    xlim = (min(lo for lo, hi in xlims), max(hi for lo, hi in xlims))
    for ax in axes:
        ax.set_xlim(xlim)
        ax.set_ylim(0, QUANTILE_DROP)

    axes[0].set_ylabel('CDF')
    fig.suptitle(f'{KERNEL_LABELS.get(kernel, kernel)}  np={np_val}  size={size}  CDF<=q{QUANTILE_DROP}')

    if SAVE_FIG:
        out = OUT_DIR / f'{kernel}_np{np_val}_size{size}_tm_tr_by_host.png'
        fig.savefig(out, dpi=220, bbox_inches='tight')
        print(out)

    plt.show()
# Out:
# /astrum/home/hpchzy/miniconda3/envs/xfold-scripts/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /astrum/home/hpchzy/miniconda3/envs/xfold-scripts/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /tmp/ipykernel_1337354/4206567446.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(ncol=2, fontsize=8)
# /tmp/ipykernel_1337354/4206567446.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(ncol=2, fontsize=8)
# /tmp/ipykernel_1337354/4206567446.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(ncol=2, fontsize=8)
# /tmp/ipykernel_1337354/4206567446.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(ncol=2, fontsize=8)
# /tmp/ipykernel_1337354/4206567446.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(ncol=2, fontsize=8)
# /tmp/ipykernel_1337354/4206567446.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(ncol=2, fontsize=8)
